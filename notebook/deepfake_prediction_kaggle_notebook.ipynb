# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %% [markdown]
# # Steps
#
# 1. Read a video
# 2. Convert video to frames
# 3. Extract faces from frames
# 4. Make predictions on faces (predict probability)
# 5. For each file name (i.e. video) get the average probability and infer class (0/1)
# 6. Create submission.csv file

# %% [markdown]
# # Libraries

# %%
# !pip install '/kaggle/input/dlibpkg/dlib-19.19.0'
# Out:
# Processing /kaggle/input/dlibpkg/dlib-19.19.0
# Building wheels for collected packages: dlib
#   Building wheel for dlib (setup.py) ... done
#   Created wheel for dlib: filename=dlib-19.19.0-cp36-cp36m-linux_x86_64.whl size=3872032 sha256=bbe8fd546553b4ae9d6c86fc85c1cdeec6ebefe02200ae825c3a885cd68f5ea7
#   Stored in directory: /root/.cache/pip/wheels/f3/da/18/38136f7dd8e242c1cc2236d574a50f34463b8c59aab887dd79
# Successfully built dlib
# Installing collected packages: dlib
# Successfully installed dlib-19.19.0

# %%
import os
import math
import pandas as pd
import numpy as np
from glob import glob
import multiprocessing
import logging
import cv2 as cv
from tqdm import tqdm_notebook
import dlib
from tensorflow.keras import models

logging.basicConfig(format='%(name)s - %(levelname)s - %(asctime)s - %(filename)s - %(lineno)d - %(message)s', level=logging.INFO)

# %% [markdown]
# # Configs

# %%
BASE_DIR = '/kaggle/input'
OUTPUT_DIR = '/kaggle/working'
DATA_DIR = 'deepfake-detection-challenge'
VIDEOS = 'test_videos'
FRAMES = 'frames'
FACES = 'faces'
MODEL_DIR = 'inceptionv3-model'
MODEL_NAME = 'inceptionv3_facev1_augdata_17K_frames_20200327_005549.h5'

# %% [markdown]
# ### Frames to Faces

# %%
def rect_to_bb(rect):
    """
       take a bounding predicted by dlib and convert it
       to the format (x, y, w, h) as we would normally do
       with OpenCV
    """
    x = rect.left()
    y = rect.top()
    w = rect.right() - x
    h = rect.bottom() - y
    return (x, y, w, h)


def crop_faces(image):
    detector = dlib.get_frontal_face_detector()
    faces = detector(image, 1)
    cropped_faces = []
    if len(faces) > 0:
        rects, scores, idx = detector.run(image, 0)
        for rect in rects:
            if len(rects) > 0:
                (x, y, w, h) = rect_to_bb(rect)
                roi = image[(y - 50):(y + int(1.5*h)), (x - 50):(x + int(1.5*w))]
                try:
                    roi_ = cv.resize(roi, (224, 224))
                    cropped_faces.append(roi_)
                except:
                    pass
    return cropped_faces

# %% [markdown]
# # Prediction

# %%
def get_predictions(videos, model):
    cnt = 1
    predictions = []
    for video_path in videos:
        frame_pred = {}
        # setting up VideoCapture
        name = video_path.split('/')[-1]
        print(f"getting frames of: {name}")
        cap = cv.VideoCapture(video_path)
        frame_pred.update({"filename": name})
        # getting the frames
        frameRate = cap.get(5)  #to get the frame rate
        while(cap.isOpened()):
            frameId = cap.get(1)  #current frame number
            ret, frame = cap.read()
            if (ret) & (frameId % math.floor(frameRate) == 0):
                # face detection
                cropped_faces = crop_faces(frame)
                if len(cropped_faces) > 0:
                    for face in cropped_faces:
                        print("face(s) are cropped, sending to prediction")
                        face = face/255
                        face_ = np.expand_dims(face, axis=0)
                        label = model.predict_classes(face_)[0][0]
                        prob = model.predict_proba(face_)[0][0]
                        print(f"probability of fake: {prob}")
                        frame_pred.update({"label": label})
                        frame_pred.update({"prob": prob})
                        predictions.append(frame_pred)
            cap.release()
        print(f"video count so far: {cnt}")
        print("="*50)
        cnt += 1
    return predictions

# %%
videos_dir = os.path.join(BASE_DIR, DATA_DIR, VIDEOS)
videos = glob(os.path.join(videos_dir, '*.mp4'))
model = models.load_model(os.path.join(BASE_DIR, MODEL_DIR, MODEL_NAME))
predictions = get_predictions(videos, model)
# Out:
# getting frames of: ywauoonmlr.mp4
# video count so far: 1
# ==================================================
# getting frames of: sfsayjgzrh.mp4
# video count so far: 2
# ==================================================
# getting frames of: sngjsueuhs.mp4
# video count so far: 3
# ==================================================
# getting frames of: eryjktdexi.mp4
# video count so far: 4
# ==================================================
# getting frames of: nwvloufjty.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9973004460334778
# video count so far: 5
# ==================================================
# getting frames of: sjkfxrlxxs.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999978542327881
# video count so far: 6
# ==================================================
# getting frames of: rtpbawlmxr.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9995809197425842
# video count so far: 7
# ==================================================
# getting frames of: rxdoimqble.mp4
# video count so far: 8
# ==================================================
# getting frames of: ljauauuyka.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9883151054382324
# video count so far: 9
# ==================================================
# getting frames of: lbfqksftuo.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9998272061347961
# video count so far: 10
# ==================================================
# getting frames of: gfgcwxkbjd.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.8952726721763611
# video count so far: 11
# ==================================================
# getting frames of: xjvxtuakyd.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9935089349746704
# video count so far: 12
# ==================================================
# getting frames of: zfobicuigx.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.14406906068325043
# video count so far: 13
# ==================================================
# getting frames of: blszgmxkvu.mp4
# video count so far: 14
# ==================================================
# getting frames of: zmxeiipnqb.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9988425374031067
# video count so far: 15
# ==================================================
# getting frames of: fwykevubzy.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.746103048324585
# video count so far: 16
# ==================================================
# getting frames of: phjvutxpoi.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999767541885376
# video count so far: 17
# ==================================================
# getting frames of: kmcdjxmnoa.mp4
# video count so far: 18
# ==================================================
# getting frames of: oyqgwjdwaj.mp4
# video count so far: 19
# ==================================================
# getting frames of: mxahsihabr.mp4
# video count so far: 20
# ==================================================
# getting frames of: ouaowjmigq.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9742087721824646
# video count so far: 21
# ==================================================
# getting frames of: itfsvvmslp.mp4
# video count so far: 22
# ==================================================
# getting frames of: uxuvkrjhws.mp4
# video count so far: 23
# ==================================================
# getting frames of: rklawjhbpv.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9248830676078796
# video count so far: 24
# ==================================================
# getting frames of: ywxpquomgt.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.6656672954559326
# video count so far: 25
# ==================================================
# getting frames of: srfefmyjvt.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9742510914802551
# video count so far: 26
# ==================================================
# getting frames of: gbnzicjyhz.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999983310699463
# video count so far: 27
# ==================================================
# getting frames of: sktpeppbkc.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999605417251587
# video count so far: 28
# ==================================================
# getting frames of: scrbqgpvzz.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999946355819702
# video count so far: 29
# ==================================================
# getting frames of: gpsxfxrjrr.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999998807907104
# video count so far: 30
# ==================================================
# getting frames of: icbsahlivv.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999366998672485
# video count so far: 31
# ==================================================
# getting frames of: eyguqfmgzh.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.5064782500267029
# video count so far: 32
# ==================================================
# getting frames of: vbcgoyxsvn.mp4
# video count so far: 33
# ==================================================
# getting frames of: xphdfgmfmz.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999970197677612
# video count so far: 34
# ==================================================
# getting frames of: bjyaxvggle.mp4
# video count so far: 35
# ==================================================
# getting frames of: tjywwgftmv.mp4
# video count so far: 36
# ==================================================
# getting frames of: irqzdokcws.mp4
# video count so far: 37
# ==================================================
# getting frames of: gochxzemmq.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999128580093384
# video count so far: 38
# ==================================================
# getting frames of: rukyxomwcx.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9683706760406494
# video count so far: 39
# ==================================================
# getting frames of: rerpivllud.mp4
# video count so far: 40
# ==================================================
# getting frames of: hzoiotcykp.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9399211406707764
# video count so far: 41
# ==================================================
# getting frames of: dzkyxbbqkr.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999998807907104
# video count so far: 42
# ==================================================
# getting frames of: lpkgabskbw.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9857775568962097
# video count so far: 43
# ==================================================
# getting frames of: nwvsbmyndn.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9931495785713196
# video count so far: 44
# ==================================================
# getting frames of: fqgypsunzr.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9860306978225708
# video count so far: 45
# ==================================================
# getting frames of: btdxnajogv.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9961695075035095
# video count so far: 46
# ==================================================
# getting frames of: cnxccbjlct.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9996380805969238
# video count so far: 47
# ==================================================
# getting frames of: sjwywglgym.mp4
# video count so far: 48
# ==================================================
# getting frames of: dpmgoiwhuf.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9159631133079529
# video count so far: 49
# ==================================================
# getting frames of: dvtpwatuja.mp4
# video count so far: 50
# ==================================================
# getting frames of: wcvsqnplsk.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9610283374786377
# video count so far: 51
# ==================================================
# getting frames of: qlvsqdroqo.mp4
# video count so far: 52
# ==================================================
# getting frames of: dzojiwfvba.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9930192828178406
# video count so far: 53
# ==================================================
# getting frames of: rcecrgeotc.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9983671307563782
# video count so far: 54
# ==================================================
# getting frames of: shnsajrsow.mp4
# video count so far: 55
# ==================================================
# getting frames of: ptbnewtvon.mp4
# video count so far: 56
# ==================================================
# getting frames of: hqzwudvhih.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999493360519409
# video count so far: 57
# ==================================================
# getting frames of: nycmyuzpml.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9768307209014893
# video count so far: 58
# ==================================================
# getting frames of: wcssbghcpc.mp4
# video count so far: 59
# ==================================================
# getting frames of: llplvmcvbl.mp4
# video count so far: 60
# ==================================================
# getting frames of: wclvkepakb.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9655624032020569
# video count so far: 61
# ==================================================
# getting frames of: vajkicalux.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9747999906539917
# video count so far: 62
# ==================================================
# getting frames of: cxsvvnxpyz.mp4
# video count so far: 63
# ==================================================
# getting frames of: mwwploizlj.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9937148690223694
# video count so far: 64
# ==================================================
# getting frames of: yljecirelf.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9671152830123901
# video count so far: 65
# ==================================================
# getting frames of: eqslzbqfea.mp4
# video count so far: 66
# ==================================================
# getting frames of: eppyqpgewp.mp4
# video count so far: 67
# ==================================================
# getting frames of: wjhpisoeaj.mp4
# video count so far: 68
# ==================================================
# getting frames of: ibxfxggtqh.mp4
# video count so far: 69
# ==================================================
# getting frames of: dtozwcapoa.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9435322880744934
# video count so far: 70
# ==================================================
# getting frames of: vhbbwdflyh.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9807146191596985
# video count so far: 71
# ==================================================
# getting frames of: doniqevxeg.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9797489047050476
# video count so far: 72
# ==================================================
# getting frames of: rmlzgerevr.mp4
# video count so far: 73
# ==================================================
# getting frames of: heiyoojifp.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999406337738037
# video count so far: 74
# ==================================================
# getting frames of: tgawasvbbr.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.8468513488769531
# video count so far: 75
# ==================================================
# getting frames of: kvmpmhdxly.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9828037023544312
# video count so far: 76
# ==================================================
# getting frames of: ekvwecwltj.mp4
# video count so far: 77
# ==================================================
# getting frames of: honxqdilvv.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9997521042823792
# video count so far: 78
# ==================================================
# getting frames of: xrtvqhdibb.mp4
# video count so far: 79
# ==================================================
# getting frames of: vizerpsvbz.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9143693447113037
# video count so far: 80
# ==================================================
# getting frames of: swsaoktwgi.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9997465014457703
# video count so far: 81
# ==================================================
# getting frames of: zxacihctqp.mp4
# video count so far: 82
# ==================================================
# getting frames of: igpvrfjdzc.mp4
# video count so far: 83
# ==================================================
# getting frames of: jhczqfefgw.mp4
# video count so far: 84
# ==================================================
# getting frames of: waucvvmtkq.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9997441172599792
# video count so far: 85
# ==================================================
# getting frames of: txnmkabufs.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9892600774765015
# video count so far: 86
# ==================================================
# getting frames of: vjljdfopjg.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9997279047966003
# video count so far: 87
# ==================================================
# getting frames of: toinozytsp.mp4
# video count so far: 88
# ==================================================
# getting frames of: pqthmvwonf.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.999990701675415
# video count so far: 89
# ==================================================
# getting frames of: oefukgnvel.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9963843822479248
# video count so far: 90
# ==================================================
# getting frames of: cnpanmywno.mp4
# video count so far: 91
# ==================================================
# getting frames of: fmhiujydwo.mp4
# video count so far: 92
# ==================================================
# getting frames of: jawgcggquk.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9679431915283203
# video count so far: 93
# ==================================================
# getting frames of: ybbrkacebd.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999887943267822
# video count so far: 94
# ==================================================
# getting frames of: cjkctqqakb.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.7303083539009094
# video count so far: 95
# ==================================================
# getting frames of: pdswwyyntw.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9925422668457031
# video count so far: 96
# ==================================================
# getting frames of: ocgdbrgmtq.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9993194341659546
# video count so far: 97
# ==================================================
# getting frames of: dmmvuaikkv.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.985009491443634
# video count so far: 98
# ==================================================
# getting frames of: mllzkpgatp.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9530137181282043
# video count so far: 99
# ==================================================
# getting frames of: oysopgovhu.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9981862902641296
# video count so far: 100
# ==================================================
# getting frames of: lujvyveojc.mp4
# video count so far: 101
# ==================================================
# getting frames of: yhylappzid.mp4
# video count so far: 102
# ==================================================
# getting frames of: mkmgcxaztt.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9734607338905334
# video count so far: 103
# ==================================================
# getting frames of: iksxzpqxzi.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999943971633911
# video count so far: 104
# ==================================================
# getting frames of: yaxgpxhavq.mp4
# video count so far: 105
# ==================================================
# getting frames of: ptbfnkajyi.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9986452460289001
# video count so far: 106
# ==================================================
# getting frames of: imdmhwkkni.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9733171463012695
# video count so far: 107
# ==================================================
# getting frames of: sylnrepacf.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9989959597587585
# video count so far: 108
# ==================================================
# getting frames of: yxirnfyijn.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9984326958656311
# video count so far: 109
# ==================================================
# getting frames of: ryxaqpfubf.mp4
# video count so far: 110
# ==================================================
# getting frames of: yllztsrwjw.mp4
# video count so far: 111
# ==================================================
# getting frames of: gfcycflhbo.mp4
# video count so far: 112
# ==================================================
# getting frames of: knxltsvzyu.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999122619628906
# video count so far: 113
# ==================================================
# getting frames of: ndikguxzek.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999943971633911
# video count so far: 114
# ==================================================
# getting frames of: dxgnpnowgk.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9916644096374512
# video count so far: 115
# ==================================================
# getting frames of: uvrzaczrbx.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9915959239006042
# video count so far: 116
# ==================================================
# getting frames of: wynotylpnm.mp4
# video count so far: 117
# ==================================================
# getting frames of: kezwvsxxzj.mp4
# video count so far: 118
# ==================================================
# getting frames of: cqhwesrciw.mp4
# video count so far: 119
# ==================================================
# getting frames of: udxqbhgvvx.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9895474910736084
# video count so far: 120
# ==================================================
# getting frames of: dyjklprkoc.mp4
# video count so far: 121
# ==================================================
# getting frames of: rktrpsdlci.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9994934797286987
# video count so far: 122
# ==================================================
# getting frames of: bofrwgeyjo.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999929666519165
# video count so far: 123
# ==================================================
# getting frames of: hefisnapds.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9985741376876831
# video count so far: 124
# ==================================================
# getting frames of: wnlubukrki.mp4
# video count so far: 125
# ==================================================
# getting frames of: rmufsuogzn.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9997630715370178
# video count so far: 126
# ==================================================
# getting frames of: cekarydqba.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9957914352416992
# video count so far: 127
# ==================================================
# getting frames of: pxcfrszlgi.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9991576671600342
# video count so far: 128
# ==================================================
# getting frames of: qooxnxqqjb.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.918627142906189
# video count so far: 129
# ==================================================
# getting frames of: fxuxxtryjn.mp4
# video count so far: 130
# ==================================================
# getting frames of: ylxwcwhjjd.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9996895790100098
# video count so far: 131
# ==================================================
# getting frames of: qxyrtwozyw.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9471672177314758
# video count so far: 132
# ==================================================
# getting frames of: coujjnypba.mp4
# video count so far: 133
# ==================================================
# getting frames of: hclsparpth.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9998847246170044
# video count so far: 134
# ==================================================
# getting frames of: txmnoyiyte.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.987878143787384
# video count so far: 135
# ==================================================
# getting frames of: didzujjhtg.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9929519295692444
# video count so far: 136
# ==================================================
# getting frames of: mkzaekkvej.mp4
# video count so far: 137
# ==================================================
# getting frames of: ggzjfrirjh.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.974129855632782
# video count so far: 138
# ==================================================
# getting frames of: xugmhbetrw.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999246597290039
# video count so far: 139
# ==================================================
# getting frames of: lpgxwdgnio.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.997793436050415
# video count so far: 140
# ==================================================
# getting frames of: ytddugrwph.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9900304079055786
# video count so far: 141
# ==================================================
# getting frames of: qhkzlnzruj.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9778804779052734
# video count so far: 142
# ==================================================
# getting frames of: ziipxxchai.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.6306509971618652
# video count so far: 143
# ==================================================
# getting frames of: qarqtkvgby.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9978888630867004
# video count so far: 144
# ==================================================
# getting frames of: xitgdpzbxv.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.944892168045044
# video count so far: 145
# ==================================================
# getting frames of: zcxcmneefk.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9978606104850769
# video count so far: 146
# ==================================================
# getting frames of: gfdjzwnpyp.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999282360076904
# video count so far: 147
# ==================================================
# getting frames of: nthpnwylxo.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999743700027466
# video count so far: 148
# ==================================================
# getting frames of: hxwtsaydal.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9895778894424438
# face(s) are cropped, sending to prediction
# probability of fake: 0.9596686959266663
# video count so far: 149
# ==================================================
# getting frames of: hnfwagcxdf.mp4
# video count so far: 150
# ==================================================
# getting frames of: zgbhzkditd.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9998619556427002
# video count so far: 151
# ==================================================
# getting frames of: zzmgnglanj.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9947970509529114
# video count so far: 152
# ==================================================
# getting frames of: ojsxxkalat.mp4
# video count so far: 153
# ==================================================
# getting frames of: zbgssotnjm.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9982905983924866
# video count so far: 154
# ==================================================
# getting frames of: uhakqelqri.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.985353946685791
# video count so far: 155
# ==================================================
# getting frames of: rfwxcinshk.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999961853027344
# video count so far: 156
# ==================================================
# getting frames of: syxobtuucp.mp4
# video count so far: 157
# ==================================================
# getting frames of: sufvvwmbha.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999212026596069
# video count so far: 158
# ==================================================
# getting frames of: kcjvhgvhpt.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9955804944038391
# video count so far: 159
# ==================================================
# getting frames of: csnkohqxdv.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9980047345161438
# video count so far: 160
# ==================================================
# getting frames of: zgjosltkie.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9896916747093201
# video count so far: 161
# ==================================================
# getting frames of: jiavqbrkyk.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.3921425938606262
# video count so far: 162
# ==================================================
# getting frames of: ayipraspbn.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 1.0
# video count so far: 163
# ==================================================
# getting frames of: vvfszaosiv.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9071350693702698
# video count so far: 164
# ==================================================
# getting frames of: xcruhaccxc.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9996871948242188
# video count so far: 165
# ==================================================
# getting frames of: espkiocpxq.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9993997812271118
# video count so far: 166
# ==================================================
# getting frames of: apvzjkvnwn.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.999903678894043
# video count so far: 167
# ==================================================
# getting frames of: sjinmmbipg.mp4
# video count so far: 168
# ==================================================
# getting frames of: vssmlqoiti.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.5734209418296814
# video count so far: 169
# ==================================================
# getting frames of: lnhkjhyhvw.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999966621398926
# video count so far: 170
# ==================================================
# getting frames of: lyoslorecs.mp4
# video count so far: 171
# ==================================================
# getting frames of: cqxxumarvp.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9943097829818726
# video count so far: 172
# ==================================================
# getting frames of: dkuqbduxev.mp4
# video count so far: 173
# ==================================================
# getting frames of: jiswxuqzyz.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.945941686630249
# video count so far: 174
# ==================================================
# getting frames of: yxvmusxvcz.mp4
# video count so far: 175
# ==================================================
# getting frames of: oaguiggjyv.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.985210120677948
# video count so far: 176
# ==================================================
# getting frames of: tejfudfgpq.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9993371367454529
# video count so far: 177
# ==================================================
# getting frames of: tynfsthodx.mp4
# video count so far: 178
# ==================================================
# getting frames of: eywdmustbb.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9903333783149719
# video count so far: 179
# ==================================================
# getting frames of: qcbkztamqc.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.1620442420244217
# video count so far: 180
# ==================================================
# getting frames of: pdufsewrec.mp4
# video count so far: 181
# ==================================================
# getting frames of: fjrueenjyp.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999945163726807
# video count so far: 182
# ==================================================
# getting frames of: zyufpqvpyu.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9008291959762573
# video count so far: 183
# ==================================================
# getting frames of: ztyuiqrhdk.mp4
# video count so far: 184
# ==================================================
# getting frames of: tjuihawuqm.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9906987547874451
# face(s) are cropped, sending to prediction
# probability of fake: 0.9252059459686279
# video count so far: 185
# ==================================================
# getting frames of: mnowxangqx.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9986314177513123
# video count so far: 186
# ==================================================
# getting frames of: etdliwticv.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.999998927116394
# video count so far: 187
# ==================================================
# getting frames of: nikynwcvuh.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9883913397789001
# video count so far: 188
# ==================================================
# getting frames of: owaogcehvc.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9989604949951172
# video count so far: 189
# ==================================================
# getting frames of: nxnmkytwze.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9463374018669128
# video count so far: 190
# ==================================================
# getting frames of: qqnlrngaft.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9961323738098145
# video count so far: 191
# ==================================================
# getting frames of: usqqvxcjmg.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9944902658462524
# video count so far: 192
# ==================================================
# getting frames of: dxfdovivlw.mp4
# video count so far: 193
# ==================================================
# getting frames of: adohdulfwb.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9812193512916565
# video count so far: 194
# ==================================================
# getting frames of: ekboxwrwuv.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9900981783866882
# video count so far: 195
# ==================================================
# getting frames of: nxgzmgzkfv.mp4
# video count so far: 196
# ==================================================
# getting frames of: ncoeewrdlo.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999969005584717
# video count so far: 197
# ==================================================
# getting frames of: fjxovgmwnm.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9887545108795166
# video count so far: 198
# ==================================================
# getting frames of: cosghhimnd.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9846412539482117
# video count so far: 199
# ==================================================
# getting frames of: rnfcjxynfa.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.997632622718811
# video count so far: 200
# ==================================================
# getting frames of: esjdyghhog.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9977450370788574
# video count so far: 201
# ==================================================
# getting frames of: lbigytrrtr.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9895586967468262
# video count so far: 202
# ==================================================
# getting frames of: ljouzjaqqe.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9895190596580505
# video count so far: 203
# ==================================================
# getting frames of: gkutjglghz.mp4
# video count so far: 204
# ==================================================
# getting frames of: dvwpvqdflx.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9993762373924255
# video count so far: 205
# ==================================================
# getting frames of: yzuestxcbq.mp4
# video count so far: 206
# ==================================================
# getting frames of: dsnxgrfdmd.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9853640198707581
# video count so far: 207
# ==================================================
# getting frames of: rrrfjhugvb.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9845645427703857
# video count so far: 208
# ==================================================
# getting frames of: zuwwbbusgl.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9834163188934326
# video count so far: 209
# ==================================================
# getting frames of: papagllumt.mp4
# video count so far: 210
# ==================================================
# getting frames of: fpevfidstw.mp4
# video count so far: 211
# ==================================================
# getting frames of: okgelildpc.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999252557754517
# video count so far: 212
# ==================================================
# getting frames of: vokrpfjpeb.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9953542947769165
# video count so far: 213
# ==================================================
# getting frames of: rcjfxxhcal.mp4
# video count so far: 214
# ==================================================
# getting frames of: bkuzquigyt.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9998339414596558
# video count so far: 215
# ==================================================
# getting frames of: fmvvmcbdrw.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999998807907104
# video count so far: 216
# ==================================================
# getting frames of: ecumyiowzs.mp4
# video count so far: 217
# ==================================================
# getting frames of: fddmkqjwsh.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9317413568496704
# video count so far: 218
# ==================================================
# getting frames of: gccnvdoknm.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999531507492065
# video count so far: 219
# ==================================================
# getting frames of: sodvtfqbpf.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999891519546509
# video count so far: 220
# ==================================================
# getting frames of: mdfndlljvt.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9968878626823425
# video count so far: 221
# ==================================================
# getting frames of: ystdtnetgj.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9470201730728149
# video count so far: 222
# ==================================================
# getting frames of: fopjiyxiqd.mp4
# video count so far: 223
# ==================================================
# getting frames of: hsbljbsgxr.mp4
# video count so far: 224
# ==================================================
# getting frames of: blnmxntbey.mp4
# video count so far: 225
# ==================================================
# getting frames of: kqlvggiqee.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9959443211555481
# video count so far: 226
# ==================================================
# getting frames of: fnxgqcvlsd.mp4
# video count so far: 227
# ==================================================
# getting frames of: bzvzpwrabw.mp4
# video count so far: 228
# ==================================================
# getting frames of: bnuwxhfahw.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.999777615070343
# video count so far: 229
# ==================================================
# getting frames of: jytrvwlewz.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9997549653053284
# video count so far: 230
# ==================================================
# getting frames of: bfjsthfhbd.mp4
# video count so far: 231
# ==================================================
# getting frames of: jsysgmycsx.mp4
# video count so far: 232
# ==================================================
# getting frames of: kmqkiihrmj.mp4
# video count so far: 233
# ==================================================
# getting frames of: ihglzxzroo.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.999421238899231
# video count so far: 234
# ==================================================
# getting frames of: qsjiypnjwi.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9994432330131531
# video count so far: 235
# ==================================================
# getting frames of: dcqodpzomd.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999728202819824
# video count so far: 236
# ==================================================
# getting frames of: uubgqnvfdl.mp4
# video count so far: 237
# ==================================================
# getting frames of: qdqdsaiitt.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9993376135826111
# video count so far: 238
# ==================================================
# getting frames of: gqnaxievjx.mp4
# video count so far: 239
# ==================================================
# getting frames of: bdshuoldwx.mp4
# video count so far: 240
# ==================================================
# getting frames of: bfdopzvxbi.mp4
# video count so far: 241
# ==================================================
# getting frames of: uhrqlmlclw.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9841230511665344
# video count so far: 242
# ==================================================
# getting frames of: ipkpxvwroe.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999388456344604
# video count so far: 243
# ==================================================
# getting frames of: wixbuuzygv.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.17520685493946075
# video count so far: 244
# ==================================================
# getting frames of: hitfycdavv.mp4
# video count so far: 245
# ==================================================
# getting frames of: jquevmhdvc.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9996126294136047
# video count so far: 246
# ==================================================
# getting frames of: mxlipjhmqk.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9882277846336365
# video count so far: 247
# ==================================================
# getting frames of: aayfryxljh.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9993622899055481
# video count so far: 248
# ==================================================
# getting frames of: ajiyrjfyzp.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.7902671098709106
# video count so far: 249
# ==================================================
# getting frames of: vnlzxqwthl.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9936554431915283
# video count so far: 250
# ==================================================
# getting frames of: yarpxfqejd.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9873615503311157
# video count so far: 251
# ==================================================
# getting frames of: ilqwcbprqa.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9458155035972595
# video count so far: 252
# ==================================================
# getting frames of: snlyjbnpgw.mp4
# video count so far: 253
# ==================================================
# getting frames of: qswlzfgcgj.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.999703586101532
# face(s) are cropped, sending to prediction
# probability of fake: 0.9991278052330017
# video count so far: 254
# ==================================================
# getting frames of: ypbtpunjvm.mp4
# video count so far: 255
# ==================================================
# getting frames of: hweshqpfwe.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9995942711830139
# video count so far: 256
# ==================================================
# getting frames of: nxzgekegsp.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999144077301025
# video count so far: 257
# ==================================================
# getting frames of: xxzefxwyku.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.8434416055679321
# video count so far: 258
# ==================================================
# getting frames of: hcanfkwivl.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9980117082595825
# video count so far: 259
# ==================================================
# getting frames of: vurjckblge.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999250173568726
# video count so far: 260
# ==================================================
# getting frames of: yoyhmxtrys.mp4
# video count so far: 261
# ==================================================
# getting frames of: czfqlbcfpa.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9709922671318054
# video count so far: 262
# ==================================================
# getting frames of: ytopzxrswu.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999990463256836
# video count so far: 263
# ==================================================
# getting frames of: bwdmzwhdnw.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999880790710449
# video count so far: 264
# ==================================================
# getting frames of: fzvpbrzssi.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.999881386756897
# video count so far: 265
# ==================================================
# getting frames of: jzmzdispyo.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.5346916913986206
# video count so far: 266
# ==================================================
# getting frames of: xhtppuyqdr.mp4
# video count so far: 267
# ==================================================
# getting frames of: bcbqxhziqz.mp4
# video count so far: 268
# ==================================================
# getting frames of: hzssdinxec.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9896548986434937
# video count so far: 269
# ==================================================
# getting frames of: uqvxjfpwdo.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999997615814209
# video count so far: 270
# ==================================================
# getting frames of: rfjuhbnlro.mp4
# video count so far: 271
# ==================================================
# getting frames of: mszblrdprw.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999961853027344
# video count so far: 272
# ==================================================
# getting frames of: eisofhptvk.mp4
# video count so far: 273
# ==================================================
# getting frames of: yietrwuncf.mp4
# video count so far: 274
# ==================================================
# getting frames of: pxjkzvqomp.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9768755435943604
# video count so far: 275
# ==================================================
# getting frames of: ucthmsajay.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9735802412033081
# video count so far: 276
# ==================================================
# getting frames of: sznkemeqro.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9992245435714722
# video count so far: 277
# ==================================================
# getting frames of: mwnibuujwz.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9419102072715759
# video count so far: 278
# ==================================================
# getting frames of: zfrrixsimm.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9992544054985046
# video count so far: 279
# ==================================================
# getting frames of: mohiqoogpb.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9739722609519958
# video count so far: 280
# ==================================================
# getting frames of: pcoxcmtroa.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9855217933654785
# video count so far: 281
# ==================================================
# getting frames of: demuhxssgl.mp4
# video count so far: 282
# ==================================================
# getting frames of: qlqhjcshpk.mp4
# video count so far: 283
# ==================================================
# getting frames of: jyfvaequfg.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9986398816108704
# video count so far: 284
# ==================================================
# getting frames of: temeqbmzxu.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9821385145187378
# video count so far: 285
# ==================================================
# getting frames of: vtunvalyji.mp4
# video count so far: 286
# ==================================================
# getting frames of: oelqpetgwj.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999959468841553
# video count so far: 287
# ==================================================
# getting frames of: xdezcezszc.mp4
# video count so far: 288
# ==================================================
# getting frames of: halvwiltfs.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9993925094604492
# video count so far: 289
# ==================================================
# getting frames of: vwxednhlwz.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9942936301231384
# video count so far: 290
# ==================================================
# ...
# probability of fake: 0.96306312084198
# video count so far: 304
# ==================================================
# getting frames of: pcyswtgick.mp4
# video count so far: 305
# ==================================================
# getting frames of: hevcclcklc.mp4
# video count so far: 306
# ==================================================
# getting frames of: ggdpclfcgk.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9926637411117554
# video count so far: 307
# ==================================================
# getting frames of: hfsvqabzfq.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9994454979896545
# video count so far: 308
# ==================================================
# getting frames of: vmxfwxgdei.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9996030926704407
# video count so far: 309
# ==================================================
# getting frames of: gcdtglsoqj.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9987301230430603
# video count so far: 310
# ==================================================
# getting frames of: nkhzxomani.mp4
# video count so far: 311
# ==================================================
# getting frames of: bvpeerislp.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9967195391654968
# video count so far: 312
# ==================================================
# getting frames of: keioymnobc.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.7792303562164307
# video count so far: 313
# ==================================================
# getting frames of: aqrsylrzgi.mp4
# video count so far: 314
# ==================================================
# getting frames of: ddtbarpcgo.mp4
# video count so far: 315
# ==================================================
# getting frames of: ahjnxtiamx.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9796698093414307
# video count so far: 316
# ==================================================
# getting frames of: upmgtackuf.mp4
# video count so far: 317
# ==================================================
# getting frames of: bktkwbcawi.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9998668432235718
# video count so far: 318
# ==================================================
# getting frames of: axfhbpkdlc.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.999923586845398
# video count so far: 319
# ==================================================
# getting frames of: viteugozpv.mp4
# video count so far: 320
# ==================================================
# getting frames of: hyjqolupxn.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9976943135261536
# video count so far: 321
# ==================================================
# getting frames of: dnmowthjcj.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.99425208568573
# video count so far: 322
# ==================================================
# getting frames of: rvvpazsffd.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9991558790206909
# video count so far: 323
# ==================================================
# getting frames of: wmoqzxddkb.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9988969564437866
# video count so far: 324
# ==================================================
# getting frames of: prhmixykhr.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9955986738204956
# video count so far: 325
# ==================================================
# getting frames of: coqwgzpbhx.mp4
# video count so far: 326
# ==================================================
# getting frames of: mnzabbkpmt.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9948570728302002
# video count so far: 327
# ==================================================
# getting frames of: iznnzjvaxc.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9955732822418213
# video count so far: 328
# ==================================================
# getting frames of: famlupsgqm.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9947992563247681
# video count so far: 329
# ==================================================
# getting frames of: omphqltjdd.mp4
# video count so far: 330
# ==================================================
# getting frames of: huvlwkxoxm.mp4
# video count so far: 331
# ==================================================
# getting frames of: qclpbcbgeq.mp4
# video count so far: 332
# ==================================================
# getting frames of: uoccaiathd.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999899864196777
# video count so far: 333
# ==================================================
# getting frames of: nswtvttxre.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9701096415519714
# video count so far: 334
# ==================================================
# getting frames of: pqdeutauqc.mp4
# video count so far: 335
# ==================================================
# getting frames of: yxadevzohx.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9988663196563721
# video count so far: 336
# ==================================================
# getting frames of: tyjpjpglgx.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.865065336227417
# video count so far: 337
# ==================================================
# getting frames of: wqysrieiqu.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9725977778434753
# video count so far: 338
# ==================================================
# getting frames of: ooafcxxfrs.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9975590705871582
# video count so far: 339
# ==================================================
# getting frames of: acazlolrpz.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9985879063606262
# video count so far: 340
# ==================================================
# getting frames of: alrtntfxtd.mp4
# video count so far: 341
# ==================================================
# getting frames of: lebzjtusnr.mp4
# video count so far: 342
# ==================================================
# getting frames of: iorbtaarte.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.881746768951416
# video count so far: 343
# ==================================================
# getting frames of: wadvzjhwtw.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9791096448898315
# video count so far: 344
# ==================================================
# getting frames of: jsbpkpxwew.mp4
# video count so far: 345
# ==================================================
# getting frames of: dpevefkefv.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999620914459229
# video count so far: 346
# ==================================================
# getting frames of: qyyhuvqmyf.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9992325305938721
# video count so far: 347
# ==================================================
# getting frames of: ghnpsltzyn.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9913997650146484
# video count so far: 348
# ==================================================
# getting frames of: apedduehoy.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9997943043708801
# video count so far: 349
# ==================================================
# getting frames of: ncmpqwmnzb.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9819709062576294
# video count so far: 350
# ==================================================
# getting frames of: ipvwtgdlre.mp4
# video count so far: 351
# ==================================================
# getting frames of: nplviymzlg.mp4
# video count so far: 352
# ==================================================
# getting frames of: wfzjxzhdkj.mp4
# video count so far: 353
# ==================================================
# getting frames of: xmkwsnuzyq.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999234676361084
# video count so far: 354
# ==================================================
# getting frames of: tvhjcfnqtg.mp4
# video count so far: 355
# ==================================================
# getting frames of: petmyhjclt.mp4
# video count so far: 356
# ==================================================
# getting frames of: dvkdfhrpph.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9998806715011597
# video count so far: 357
# ==================================================
# getting frames of: qhsehzgxqj.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9998263716697693
# video count so far: 358
# ==================================================
# getting frames of: ekelfsnqof.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9949658513069153
# video count so far: 359
# ==================================================
# getting frames of: syuxttuyhm.mp4
# video count so far: 360
# ==================================================
# getting frames of: kowiwvrjht.mp4
# video count so far: 361
# ==================================================
# getting frames of: xljemofssi.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9998723268508911
# video count so far: 362
# ==================================================
# getting frames of: yiykshcbaz.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9990609288215637
# video count so far: 363
# ==================================================
# getting frames of: oocincvedt.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.987311840057373
# video count so far: 364
# ==================================================
# getting frames of: opvqdabdap.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9983464479446411
# video count so far: 365
# ==================================================
# getting frames of: esmqxszybs.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9959355592727661
# video count so far: 366
# ==================================================
# getting frames of: lmdyicksrv.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9890778660774231
# video count so far: 367
# ==================================================
# getting frames of: aktnlyqpah.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9951934218406677
# video count so far: 368
# ==================================================
# getting frames of: hbufmvbium.mp4
# video count so far: 369
# ==================================================
# getting frames of: vdtsbqidjb.mp4
# video count so far: 370
# ==================================================
# getting frames of: sqixhnilfm.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.998543381690979
# video count so far: 371
# ==================================================
# getting frames of: hszwwswewp.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9928268194198608
# video count so far: 372
# ==================================================
# getting frames of: cekwtyxdoo.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.7888686656951904
# video count so far: 373
# ==================================================
# getting frames of: dozjwhnedd.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999901056289673
# video count so far: 374
# ==================================================
# getting frames of: aassnaulhq.mp4
# video count so far: 375
# ==================================================
# getting frames of: ruhtnngrqv.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9654656052589417
# video count so far: 376
# ==================================================
# getting frames of: bkcyglmfci.mp4
# video count so far: 377
# ==================================================
# getting frames of: yhjlnisfel.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9700867533683777
# video count so far: 378
# ==================================================
# getting frames of: gahgyuwzbu.mp4
# video count so far: 379
# ==================================================
# getting frames of: frqfsucgao.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9993308782577515
# video count so far: 380
# ==================================================
# getting frames of: yqhouqakbx.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9990979433059692
# video count so far: 381
# ==================================================
# getting frames of: fsdrwikhge.mp4
# video count so far: 382
# ==================================================
# getting frames of: scbdenmaed.mp4
# video count so far: 383
# ==================================================
# getting frames of: gunamloolc.mp4
# video count so far: 384
# ==================================================
# getting frames of: wvgviwnwob.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999978542327881
# video count so far: 385
# ==================================================
# getting frames of: orixbcfvdz.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999488592147827
# video count so far: 386
# ==================================================
# getting frames of: prwsfljdjo.mp4
# video count so far: 387
# ==================================================
# getting frames of: lhvjzhjxdp.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9472606778144836
# video count so far: 388
# ==================================================
# getting frames of: njzshtfmcw.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9310794472694397
# video count so far: 389
# ==================================================
# getting frames of: yronlutbgm.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9938756823539734
# video count so far: 390
# ==================================================
# getting frames of: wndursivcx.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.999245285987854
# video count so far: 391
# ==================================================
# getting frames of: temjefwaas.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999746084213257
# video count so far: 392
# ==================================================
# getting frames of: nymodlmxni.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.05087825283408165
# video count so far: 393
# ==================================================
# getting frames of: khpipxnsvx.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9999858140945435
# video count so far: 394
# ==================================================
# getting frames of: oojxonbgow.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9931581616401672
# video count so far: 395
# ==================================================
# getting frames of: wcqvzujamg.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9935784339904785
# video count so far: 396
# ==================================================
# getting frames of: psesikjaxx.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9988600015640259
# video count so far: 397
# ==================================================
# getting frames of: lnjkpdviqb.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9990637898445129
# video count so far: 398
# ==================================================
# getting frames of: hierggamuo.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9892907738685608
# video count so far: 399
# ==================================================
# getting frames of: evysmtpnrf.mp4
# face(s) are cropped, sending to prediction
# probability of fake: 0.9990090131759644
# video count so far: 400
# ==================================================

# %%
predictions_df = pd.DataFrame(predictions)
predictions_df.to_csv(os.path.join(OUTPUT_DIR, 'submission.csv'), index=False)

# %%
predictions_df.head()
# Out:
#          filename  label      prob
# 0  nwvloufjty.mp4      1  0.997300
# 1  sjkfxrlxxs.mp4      1  0.999998
# 2  rtpbawlmxr.mp4      1  0.999581
# 3  ljauauuyka.mp4      1  0.988315
# 4  lbfqksftuo.mp4      1  0.999827

# %%
predictions_df[]
